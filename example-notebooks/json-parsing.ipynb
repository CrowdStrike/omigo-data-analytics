# %%
# Basic Imports
import os
from omigo_core import dataframe
from omigo_hydra import hydra
import json
import urllib.parse

# %%
# Create simple DF object having json strings as column values
def create_data1():
    # Create a simple tsv object with json data
    x = dataframe.new_with_cols(["record", "json"])
    
    # Mulitple hashmaps converted to json strings. As a best practice url encode textual data
    json_str1 = json.dumps({"name": "A1", "age": 20, "state": "CA"})
    json_str2 = json.dumps({"name": "A2", "age": 23, "state": "NY"})
    json_str3 = json.dumps({"name": "A3", "age": 42, "state": "WA"})

    # Add the json strings as rows
    return x \
        .add_map_as_row({"record": "1", "json": urllib.parse.quote_plus(json_str1)}) \
        .add_map_as_row({"record": "2", "json": urllib.parse.quote_plus(json_str2)}) \
        .add_map_as_row({"record": "3", "json": urllib.parse.quote_plus(json_str3)})

# %%
# read sample data
x1 = create_data1()
x1.to_df()
# Out:
# [WARN ONCE ONLY]: replace_spl_white_spaces_with_space_noop: called. Check code
#    record                                               json
# 0     1.0  %7B%22name%22%3A+%22A1%22%2C+%22age%22%3A+20%2...
# 1     2.0  %7B%22name%22%3A+%22A2%22%2C+%22age%22%3A+23%2...
# 2     3.0  %7B%22name%22%3A+%22A3%22%2C+%22age%22%3A+42%2...

# %%
# use explode_json() api to convert the json strings to tabular structure.
# Notice the special variables __json_index__. When the json element is an array,
# the added index reflects which output rows came from the same json
y1 = x1.explode_json("json", prefix = "parsed")
y1.to_df()
# Out:
# [WARN ONCE ONLY]: explode_json: merge_list_method value is None. Using default value: cogroup
# [WARN ONCE ONLY]: explode_json: collapse_primitive_list value is None. Using default value: True
# [WARN ONCE ONLY]: explode_json: collapse value is None. Using default value: True
# [WARN ONCE ONLY]: explode_json: default_val value is None. Using default value:
# [WARN ONCE ONLY]: explode_json: join_col value is None. Using default value: ,
# [WARN ONCE ONLY]: explode_json: validate is called
# [WARN ONCE ONLY]: explode_json: explode: calling validate here
#    parsed:__json_index__  record  parsed:age parsed:name parsed:state
# 0                    1.0     1.0        20.0          A1           CA
# 1                    2.0     2.0        23.0          A2           NY
# 2                    3.0     3.0        42.0          A3           WA

# %%
# Create more complex TSV object having multiple level json strings as column values
def create_data2():
    # Create a simple tsv object with json data
    x = dataframe.new_with_cols(["record", "json"])
    
    # Mulitple hashmaps converted to json strings. As a best practice url encode textual data
    json_str1 = json.dumps({"name": "A1", "age": 20, "state": "CA", "education": [{"degree": "BS", "year": "2000"}]})
    json_str2 = json.dumps({"name": "A2", "age": 23, "state": "NY", "education": [{"degree": "BS", "year": "2004"}, {"degree": "MS", "year": "2006"}]})
    json_str3 = json.dumps({"name": "A3", "age": 42, "state": "WA", "education": [{"degree": "MS", "year": "2010"}, {"degree": "PHD", "year": "2015"}]})

    # Add the json strings as rows
    return x \
        .add_map_as_row({"record": "1", "json": urllib.parse.quote_plus(json_str1)}) \
        .add_map_as_row({"record": "2", "json": urllib.parse.quote_plus(json_str2)}) \
        .add_map_as_row({"record": "3", "json": urllib.parse.quote_plus(json_str3)})

# %%
# read sample data
x2 = create_data2()
x2.to_df()
# Out:
#    record                                               json
# 0     1.0  %7B%22name%22%3A+%22A1%22%2C+%22age%22%3A+20%2...
# 1     2.0  %7B%22name%22%3A+%22A2%22%2C+%22age%22%3A+23%2...
# 2     3.0  %7B%22name%22%3A+%22A3%22%2C+%22age%22%3A+42%2...

# %%
# use explode_json() api to convert the json strings to tabular structure.
# Notice the special variables __json_index__. When the json element is an array,
# the added index reflects which output rows came from the same json
y2 = x2 \
    .explode_json("json", prefix = "parsed")
y2.to_df()
# Out:
#    parsed:__json_index__  record  parsed:age  \
# 0                    1.0     1.0        20.0
# 1                    2.0     2.0        23.0
# 2                    2.0     2.0        23.0
# 3                    3.0     3.0        42.0
# 4                    3.0     3.0        42.0
#
#    parsed:education:__explode_json_len__ parsed:education:degree  \
# 0                                    1.0                      BS
# 1                                    2.0                      BS
# 2                                    2.0                      MS
# 3                                    2.0                      MS
# 4                                    2.0                     PHD
#
#    parsed:education:year parsed:name parsed:state
# 0                 2000.0          A1           CA
# 1                 2004.0          A2           NY
# 2                 2006.0          A2           NY
# 3                 2010.0          A3           WA
# 4                 2015.0          A3           WA
