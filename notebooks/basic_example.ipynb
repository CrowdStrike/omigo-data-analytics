# %%
from tsv_data_analytics import tsvutils

# %%
# read data. this is a publicly available data on covid cases that is available on the net
# the read() method should be used in general that takes a tsv of gzip compressed tsv
# x = read("/path/to/tsv-file.tsv.gz")
# or
# x = read("s3://bucket/path/to/tsv-file.tsv.gz")
x = tsvutils.read_url("https://github.com/owid/covid-19-data/raw/master/public/data/owid-covid-data.csv")

# %%
print(x.num_rows())
# Out:
# 132224

# %%
x.export_to_df(5)
# Out:
#   iso_code continent     location        date total_cases new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24         5.0       5.0
# 1      AFG      Asia  Afghanistan  2020-02-25         5.0       0.0
# 2      AFG      Asia  Afghanistan  2020-02-26         5.0       0.0
# 3      AFG      Asia  Afghanistan  2020-02-27         5.0       0.0
# 4      AFG      Asia  Afghanistan  2020-02-28         5.0       0.0
#
#   new_cases_smoothed total_deaths new_deaths new_deaths_smoothed  ...  \
# 0                                                                 ...
# 1                                                                 ...
# 2                                                                 ...
# 3                                                                 ...
# 4                                                                 ...
#
#   female_smokers male_smokers handwashing_facilities  \
# 0                                             37.746
# ...

# %%
# basic filtering and selection
y = x \
    .eq_str("iso_code", "USA") \
    .select(["continent", "location", "date", "new_cases", "new_deaths"]) \
    .rename("location", "country_name")

# %%
y.export_to_df(5)
# Out:
#        continent   country_name        date new_cases new_deaths
# 0  North America  United States  2020-01-22
# 1  North America  United States  2020-01-23       0.0
# 2  North America  United States  2020-01-24       1.0
# 3  North America  United States  2020-01-25       0.0
# 4  North America  United States  2020-01-26       3.0

# %%
y.show(5)
# Out:
# continent    	country_name 	date      	new_cases	new_deaths
# North America	United States	2020-01-22
# North America	United States	2020-01-23	0.0
# North America	United States	2020-01-24	1.0
# North America	United States	2020-01-25	0.0
# North America	United States	2020-01-26	3.0

# %%
tsvutils.save_to_file(y, "output.tsv.gz")
